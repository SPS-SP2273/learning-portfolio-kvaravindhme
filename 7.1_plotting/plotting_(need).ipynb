# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %%
conda install matplotlib -c conda-forge
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/kvaravindh/miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       h6caf38d_4          20 KB  conda-forge
#     brotli-bin-1.1.0           |       h6caf38d_4          17 KB  conda-forge
#     contourpy-1.3.3            |  py313hc50a443_2         254 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     fonttools-4.59.2           |  py313ha0c97b7_0         2.7 MB  conda-forge
#     freetype-2.13.3            |       hce30654_1         168 KB  conda-forge
#     icu-75.1                   |       hfee45f7_0        11.3 MB  conda-forge
#     kiwisolver-1.4.9           |  py313hf88c9ab_1          67 KB  conda-forge
#     lcms2-2.17                 |       h7eeda09_0         207 KB  conda-forge
#     lerc-4.0.0                 |       hd64df32_1         184 KB  conda-forge
#     libarchive-3.7.7           |       h7c07d2a_0         759 KB  conda-forge
#     libbrotlicommon-1.1.0      |       h6caf38d_4          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       h6caf38d_4          28 KB  conda-forge
#     libbrotlienc-1.1.0         |       h6caf38d_4         269 KB  conda-forge
#     libcurl-8.4.0              |       h2d989ff_0         341 KB  conda-forge
#     libcxx-21.1.0              |       hf598326_1         555 KB  conda-forge
#     libdeflate-1.22            |       hd74edd7_0          53 KB  conda-forge
#     libexpat-2.7.1             |       hec049ff_0          64 KB  conda-forge
#     libfreetype-2.13.3         |       hce30654_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h1d14073_1         326 KB  conda-forge
#     libiconv-1.18              |       h23cfdf5_2         733 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       h5505292_0         541 KB  conda-forge
#     libnghttp2-1.52.0          |       hae82a92_0         551 KB  conda-forge
#     libpng-1.6.50              |       h280e0eb_1         280 KB  conda-forge
#     libsolv-0.7.35             |       h5f525b2_0         418 KB  conda-forge
#     libsqlite-3.50.4           |       h4237e3c_0         881 KB  conda-forge
#     libssh2-1.11.1             |       h1590b86_0         273 KB  conda-forge
#     libtiff-4.7.0              |       hfce79cd_1         358 KB  conda-forge
#     libwebp-base-1.6.0         |       h07db88b_0         288 KB  conda-forge
#     libxcb-1.17.0              |       hdb1d25a_0         316 KB  conda-forge
#     libxml2-2.13.5             |       hbbdcc80_0         569 KB  conda-forge
#     libzlib-1.3.1              |       h8359307_2          45 KB  conda-forge
#     lzo-2.10                   |    h925e9cb_1002         149 KB  conda-forge
#     matplotlib-3.10.6          |  py313h39782a4_1          17 KB  conda-forge
#     matplotlib-base-3.10.6     |  py313h58042b9_1         7.9 MB  conda-forge
#     munkres-1.1.4              |     pyhd8ed1ab_1          15 KB  conda-forge
#     ncurses-6.5                |       h5e97a16_3         778 KB  conda-forge
#     openjpeg-2.5.3             |       h889cd5d_1         313 KB  conda-forge
#     pcre2-10.46                |       h7125dd6_0         816 KB  conda-forge
#     pillow-11.3.0              |  py313h1d270a1_1        41.0 MB  conda-forge
#     pthread-stubs-0.4          |    hd74edd7_1002           8 KB  conda-forge
#     pyparsing-3.2.3            |     pyhe01879c_2         100 KB  conda-forge
#     python-3.13.1              |hbbac1ca_100_cp313        12.2 MB  conda-forge
#     qhull-2020.2               |       h420ef59_5         504 KB  conda-forge
#     sqlite-3.50.4              |       hb5dd463_0         146 KB  conda-forge
#     tk-8.6.13                  |       h892fb3f_2         3.0 MB  conda-forge
#     xorg-libxau-1.0.12         |       h5505292_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hd74edd7_0          18 KB  conda-forge
#     zlib-1.3.1                 |       h8359307_2          76 KB  conda-forge
#     zstd-1.5.6                 |       hb46c0d2_0         396 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        89.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-h6caf38d_4
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-h6caf38d_4
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.3-py313hc50a443_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   fonttools          conda-forge/osx-arm64::fonttools-4.59.2-py313ha0c97b7_0
#   freetype           conda-forge/osx-arm64::freetype-2.13.3-hce30654_1
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.9-py313hf88c9ab_1
#   lcms2              conda-forge/osx-arm64::lcms2-2.17-h7eeda09_0
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-hd64df32_1
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-h6caf38d_4
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-h6caf38d_4
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-h6caf38d_4
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.22-hd74edd7_0
#   libexpat           conda-forge/osx-arm64::libexpat-2.7.1-hec049ff_0
#   libfreetype        conda-forge/osx-arm64::libfreetype-2.13.3-hce30654_1
#   libfreetype6       conda-forge/osx-arm64::libfreetype6-2.13.3-h1d14073_1
#   libjpeg-turbo      conda-forge/osx-arm64::libjpeg-turbo-3.1.0-h5505292_0
#   libpng             conda-forge/osx-arm64::libpng-1.6.50-h280e0eb_1
#   libsqlite          conda-forge/osx-arm64::libsqlite-3.50.4-h4237e3c_0
#   libtiff            conda-forge/osx-arm64::libtiff-4.7.0-hfce79cd_1
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.6.0-h07db88b_0
#   libxcb             conda-forge/osx-arm64::libxcb-1.17.0-hdb1d25a_0
#   libzlib            conda-forge/osx-arm64::libzlib-1.3.1-h8359307_2
#   lzo                conda-forge/osx-arm64::lzo-2.10-h925e9cb_1002
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.10.6-py313h39782a4_1
#   matplotlib-base    conda-forge/osx-arm64::matplotlib-base-3.10.6-py313h58042b9_1
#   munkres            conda-forge/noarch::munkres-1.1.4-pyhd8ed1ab_1
#   openjpeg           conda-forge/osx-arm64::openjpeg-2.5.3-h889cd5d_1
#   pillow             conda-forge/osx-arm64::pillow-11.3.0-py313h1d270a1_1
#   pthread-stubs      conda-forge/osx-arm64::pthread-stubs-0.4-hd74edd7_1002
#   pyparsing          conda-forge/noarch::pyparsing-3.2.3-pyhe01879c_2
#   qhull              conda-forge/osx-arm64::qhull-2020.2-h420ef59_5
#   xorg-libxau        conda-forge/osx-arm64::xorg-libxau-1.0.12-h5505292_0
#   xorg-libxdmcp      conda-forge/osx-arm64::xorg-libxdmcp-1.1.5-hd74edd7_0
#
# The following packages will be UPDATED:
#
#   icu                        pkgs/main::icu-73.1-h313beb8_0 --> conda-forge::icu-75.1-hfee45f7_0
#   libcxx                pkgs/main::libcxx-17.0.6-he5c5206_4 --> conda-forge::libcxx-21.1.0-hf598326_1
#   libiconv              pkgs/main::libiconv-1.16-h80987f9_3 --> conda-forge::libiconv-1.18-h23cfdf5_2
#   libsolv              pkgs/main::libsolv-0.7.30-h514c7bf_1 --> conda-forge::libsolv-0.7.35-h5f525b2_0
#   ncurses                 pkgs/main::ncurses-6.4-h313beb8_0 --> conda-forge::ncurses-6.5-h5e97a16_3
#   pcre2                   pkgs/main::pcre2-10.42-hb066dcc_1 --> conda-forge::pcre2-10.46-h7125dd6_0
#   sqlite                pkgs/main::sqlite-3.50.2-h79febb2_1 --> conda-forge::sqlite-3.50.4-hb5dd463_0
#   zlib                    pkgs/main::zlib-1.2.13-h18a0788_1 --> conda-forge::zlib-1.3.1-h8359307_2
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   libarchive         pkgs/main::libarchive-3.7.7-h8f13d7a_0 --> conda-forge::libarchive-3.7.7-h7c07d2a_0
#   libcurl              pkgs/main::libcurl-8.14.1-hb586df2_0 --> conda-forge::libcurl-8.4.0-h2d989ff_0
#   libnghttp2         pkgs/main::libnghttp2-1.57.0-h62f6fdd~ --> conda-forge::libnghttp2-1.52.0-hae82a92_0
#   libssh2              pkgs/main::libssh2-1.11.1-h3e2b118_0 --> conda-forge::libssh2-1.11.1-h1590b86_0
#   libxml2              pkgs/main::libxml2-2.13.8-h0b34f26_0 --> conda-forge::libxml2-2.13.5-hbbdcc80_0
#   python             pkgs/main::python-3.13.5-h2eb94d5_100~ --> conda-forge::python-3.13.1-hbbac1ca_100_cp313
#   tk                        pkgs/main::tk-8.6.14-h6ba3021_1 --> conda-forge::tk-8.6.13-h892fb3f_2
#   zstd                     pkgs/main::zstd-1.5.6-hfb09047_0 --> conda-forge::zstd-1.5.6-hb46c0d2_0
#
#
#
# Downloading and Extracting Packages:
# pillow-11.3.0        | 41.0 MB   |                                       |   0%
# python-3.13.1        | 12.2 MB   |                                       |   0%
#
# icu-75.1             | 11.3 MB   |                                       |   0%
#
#
# matplotlib-base-3.10 | 7.9 MB    |                                       |   0%
#
#
#
# tk-8.6.13            | 3.0 MB    |                                       |   0%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    |                                       |   0%
#
#
#
#
#
# libsqlite-3.50.4     | 881 KB    |                                       |   0%
#
#
#
#
#
#
# pcre2-10.46          | 816 KB    |                                       |   0%
#
#
#
#
#
#
#
# ncurses-6.5          | 778 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 759 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 569 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libcxx-21.1.0        | 555 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libnghttp2-1.52.0    | 551 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 541 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsolv-0.7.35       | 418 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.4.0        | 341 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 326 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 316 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.3       | 313 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# icu-75.1             | 11.3 MB   |                                       |   0%
#
#
# matplotlib-base-3.10 | 7.9 MB    |                                       |   0%
#
#
#
# tk-8.6.13            | 3.0 MB    | 1                                     |   1%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #                                     |   3%
#
# icu-75.1             | 11.3 MB   | #3                                    |   4%
#
#
#
# tk-8.6.13            | 3.0 MB    | ##5                                   |   7%
# python-3.13.1        | 12.2 MB   |                                       |   0%
#
# icu-75.1             | 11.3 MB   | ##1                                   |   6%
#
#
#
# tk-8.6.13            | 3.0 MB    | ####                                  |  11%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ##5                                   |   7%
# pillow-11.3.0        | 41.0 MB   |                                       |   0%
#
# icu-75.1             | 11.3 MB   | ##9                                   |   8%
#
#
#
# tk-8.6.13            | 3.0 MB    | #######5                              |  20%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ####1                                 |  11%
#
# icu-75.1             | 11.3 MB   | ###6                                  |  10%
#
#
#
# tk-8.6.13            | 3.0 MB    | ##########4                           |  28%
# pillow-11.3.0        | 41.0 MB   | 1                                     |   0%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ####9                                 |  13%
#
#
#
# tk-8.6.13            | 3.0 MB    | ############6                         |  34%
#
# icu-75.1             | 11.3 MB   | ####3                                 |  12%
# pillow-11.3.0        | 41.0 MB   | 2                                     |   1%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #####9                                |  16%
#
#
#
# tk-8.6.13            | 3.0 MB    | ###############7                      |  42%
# pillow-11.3.0        | 41.0 MB   | 4                                     |   1%
#
# icu-75.1             | 11.3 MB   | ####9                                 |  13%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ######6                               |  18%
#
#
#
# tk-8.6.13            | 3.0 MB    | ###################7                  |  53%
# python-3.13.1        | 12.2 MB   | ###4                                  |   9%
#
# icu-75.1             | 11.3 MB   | ######1                               |  17%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ########4                             |  23%
# pillow-11.3.0        | 41.0 MB   | 5                                     |   1%
#
#
#
# tk-8.6.13            | 3.0 MB    | #####################7                |  59%
#
#
#
# tk-8.6.13            | 3.0 MB    | #######################4              |  63%
#
# icu-75.1             | 11.3 MB   | ######9                               |  19%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #########3                            |  25%
# pillow-11.3.0        | 41.0 MB   | #                                     |   3%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ##########4                           |  28%
#
# icu-75.1             | 11.3 MB   | #######5                              |  20%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ###########4                          |  31%
# pillow-11.3.0        | 41.0 MB   | #2                                    |   3%
#
# icu-75.1             | 11.3 MB   | ########1                             |  22%
#
#
#
# tk-8.6.13            | 3.0 MB    | #########################2            |  68%
#
#
# pillow-11.3.0        | 41.0 MB   | #5                                    |   4%
#
#
#
# tk-8.6.13            | 3.0 MB    | #############################6        |  80%
#
# icu-75.1             | 11.3 MB   | ########8                             |  24%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #############3                        |  36%
# python-3.13.1        | 12.2 MB   | #####9                                |  16%
#
#
#
# pillow-11.3.0        | 41.0 MB   | #7                                    |   5%
#
# icu-75.1             | 11.3 MB   | #########4                            |  25%
#
#
# pillow-11.3.0        | 41.0 MB   | #9                                    |   5%
#
#
#
# tk-8.6.13            | 3.0 MB    | #################################7    |  91%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ###############2                      |  41%
#
# icu-75.1             | 11.3 MB   | ##########                            |  27%
# python-3.13.1        | 12.2 MB   | ######3                               |  17%
#
# icu-75.1             | 11.3 MB   | ##########5                           |  28%
#
#
#
# tk-8.6.13            | 3.0 MB    | ###################################4  |  96%
#
#
#
# pillow-11.3.0        | 41.0 MB   | ##                                    |   6%
# python-3.13.1        | 12.2 MB   | ######6                               |  18%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ################                      |  43%
#
# icu-75.1             | 11.3 MB   | ###########                           |  30%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #################7                    |  48%
# pillow-11.3.0        | 41.0 MB   | ##2                                   |   6%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | 2                                     |   1%
#
#
#
# tk-8.6.13            | 3.0 MB    | ##################################### | 100%
#
#
#
# tk-8.6.13            | 3.0 MB    | ##################################### | 100%
#
# icu-75.1             | 11.3 MB   | ###########5                          |  31%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ##3                                   |   6%
# python-3.13.1        | 12.2 MB   | #######5                              |  20%
#
# icu-75.1             | 11.3 MB   | ###########9                          |  32%
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ##3                                   |   6%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ##################6                   |  50%
# python-3.13.1        | 12.2 MB   | #######8                              |  21%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ######7                               |  18%
#
# pillow-11.3.0        | 41.0 MB   | ##4                                   |   7%
# python-3.13.1        | 12.2 MB   | ########                              |  22%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ########4                             |  23%
#
#
# pillow-11.3.0        | 41.0 MB   | ##5                                   |   7%
#
# icu-75.1             | 11.3 MB   | ############7                         |  34%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ###########2                          |  30%
# python-3.13.1        | 12.2 MB   | ########4                             |  23%
#
#
# pillow-11.3.0        | 41.0 MB   | ##6                                   |   7%
#
# icu-75.1             | 11.3 MB   | #############                         |  35%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | #############1                        |  36%
# pillow-11.3.0        | 41.0 MB   | ##7                                   |   7%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #####################                 |  57%
#
# icu-75.1             | 11.3 MB   | #############4                        |  36%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ################3                     |  44%
# python-3.13.1        | 12.2 MB   | ########9                             |  24%
#
#
# pillow-11.3.0        | 41.0 MB   | ##7                                   |   8%
#
# icu-75.1             | 11.3 MB   | #############9                        |  38%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ##################6                   |  50%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ######################7               |  62%
#
# pillow-11.3.0        | 41.0 MB   | ##8                                   |   8%
# python-3.13.1        | 12.2 MB   | #########2                            |  25%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | #####################1                |  57%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #######################8              |  64%
#
# pillow-11.3.0        | 41.0 MB   | ##9                                   |   8%
# python-3.13.1        | 12.2 MB   | #########4                            |  26%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ########################1             |  65%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ########################7             |  67%
#
# pillow-11.3.0        | 41.0 MB   | ###                                   |   8%
# python-3.13.1        | 12.2 MB   | #########6                            |  26%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ###########################3          |  74%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #########################9            |  70%
#
# pillow-11.3.0        | 41.0 MB   | ###1                                  |   9%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ##############################9       |  84%
# python-3.13.1        | 12.2 MB   | #########9                            |  27%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ###########################           |  73%
#
# pillow-11.3.0        | 41.0 MB   | ###2                                  |   9%
# python-3.13.1        | 12.2 MB   | ##########2                           |  28%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ##################################3   |  93%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ############################4         |  77%
#
# pillow-11.3.0        | 41.0 MB   | ###4                                  |   9%
#
#
#
#
# fonttools-4.59.2     | 2.7 MB    | ##################################### | 100%
# python-3.13.1        | 12.2 MB   | ##########5                           |  29%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #############################7        |  80%
#
# icu-75.1             | 11.3 MB   | ##################2                   |  49%
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ###5                                  |  10%
# python-3.13.1        | 12.2 MB   | ##########9                           |  30%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ###############################1      |  84%
#
# icu-75.1             | 11.3 MB   | ##################9                   |  51%
#
#
#
#
#
# libsqlite-3.50.4     | 881 KB    | ###########4                          |  31%
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ###6                                  |  10%
# python-3.13.1        | 12.2 MB   | ###########2                          |  30%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ################################3     |  87%
#
# icu-75.1             | 11.3 MB   | ###################6                  |  53%
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ###8                                  |  10%
# python-3.13.1        | 12.2 MB   | ###########6                          |  31%
#
#
# matplotlib-base-3.10 | 7.9 MB    | #################################6    |  91%
#
# icu-75.1             | 11.3 MB   | ####################2                 |  55%
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ###9                                  |  11%
# python-3.13.1        | 12.2 MB   | ###########9                          |  32%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ##################################8   |  94%
#
#
#
#
#
# libsqlite-3.50.4     | 881 KB    | ####################################9 | 100%
#
# icu-75.1             | 11.3 MB   | ####################9                 |  57%
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ####                                  |  11%
# python-3.13.1        | 12.2 MB   | ############2                         |  33%
#
#
#
#
#
# libsqlite-3.50.4     | 881 KB    | ##################################### | 100%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ####################################1 |  98%
#
# icu-75.1             | 11.3 MB   | #####################6                |  58%
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ####2                                 |  11%
# python-3.13.1        | 12.2 MB   | ############6                         |  34%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ##################################### | 100%
#
#
#
#
#
#
# pcre2-10.46          | 816 KB    | #######9                              |  22%
#
# pillow-11.3.0        | 41.0 MB   | ####3                                 |  12%
# python-3.13.1        | 12.2 MB   | #############                         |  35%
#
#
#
#
#
#
# pcre2-10.46          | 816 KB    | ##################8                   |  51%
#
# pillow-11.3.0        | 41.0 MB   | ####5                                 |  12%
#
#
#
#
#
#
#
# ncurses-6.5          | 778 KB    | 7                                     |   2%
# python-3.13.1        | 12.2 MB   | #############3                        |  36%
#
#
#
#
#
#
# pcre2-10.46          | 816 KB    | ###########################5          |  75%
#
#
#
#
#
#
#
# ncurses-6.5          | 778 KB    | #########1                            |  25%
#
# pillow-11.3.0        | 41.0 MB   | ####6                                 |  13%
#
#
# matplotlib-base-3.10 | 7.9 MB    | ##################################### | 100%
# python-3.13.1        | 12.2 MB   | #############7                        |  37%
#
#
#
#
#
#
# pcre2-10.46          | 816 KB    | ###################################5  |  96%
#
#
#
#
#
#
# pcre2-10.46          | 816 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# ncurses-6.5          | 778 KB    | ##################2                   |  49%
#
#
#
#
#
#
# pcre2-10.46          | 816 KB    | ##################################### | 100%
#
# pillow-11.3.0        | 41.0 MB   | ####7                                 |  13%
# python-3.13.1        | 12.2 MB   | ##############1                       |  38%
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 759 KB    | 7                                     |   2%
#
#
#
#
#
#
#
# ncurses-6.5          | 778 KB    | #############################6        |  80%
#
# pillow-11.3.0        | 41.0 MB   | ####9                                 |  13%
# python-3.13.1        | 12.2 MB   | ##############5                       |  39%
#
#
#
#
#
#
#
# ncurses-6.5          | 778 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 759 KB    | ############4                         |  34%
#
# pillow-11.3.0        | 41.0 MB   | #####                                 |  14%
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 759 KB    | #####################                 |  57%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | 8                                     |   2%
# python-3.13.1        | 12.2 MB   | ##############9                       |  40%
#
# icu-75.1             | 11.3 MB   | ##########################5           |  72%
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | #####2                                |  14%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | ############1                         |  33%
# python-3.13.1        | 12.2 MB   | ###############3                      |  41%
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 759 KB    | ##################################### | 100%
#
# icu-75.1             | 11.3 MB   | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | ###################3                  |  52%
#
#
#
#
#
#
#
#
# libarchive-3.7.7     | 759 KB    | ##################################### | 100%
# pillow-11.3.0        | 41.0 MB   | #####3                                |  15%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 569 KB    | #                                     |   3%
#
# icu-75.1             | 11.3 MB   | ###########################9          |  75%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | ###############################5      |  85%
#
#
#
#
#
#
#
# ncurses-6.5          | 778 KB    | ##################################### | 100%
# pillow-11.3.0        | 41.0 MB   | #####5                                |  15%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 569 KB    | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libiconv-1.18        | 733 KB    | ##################################### | 100%
#
# pillow-11.3.0        | 41.0 MB   | #####6                                |  15%
# python-3.13.1        | 12.2 MB   | ################4                     |  44%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 569 KB    | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
# libcxx-21.1.0        | 555 KB    | #                                     |   3%
#
# pillow-11.3.0        | 41.0 MB   | #####8                                |  16%
# python-3.13.1        | 12.2 MB   | ################8                     |  46%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 569 KB    | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
# libcxx-21.1.0        | 555 KB    | #############8                        |  37%
#
#
#
#
#
#
#
#
#
#
# libxml2-2.13.5       | 569 KB    | ##################################### | 100%
#
# icu-75.1             | 11.3 MB   | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
# libnghttp2-1.52.0    | 551 KB    | #                                     |   3%
# python-3.13.1        | 12.2 MB   | #################3                    |  47%
#
#
#
#
#
#
#
#
#
#
#
# libcxx-21.1.0        | 555 KB    | #############################8        |  81%
#
# icu-75.1             | 11.3 MB   | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
# libcxx-21.1.0        | 555 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ######1                               |  17%
# python-3.13.1        | 12.2 MB   | #################6                    |  48%
#
#
#
#
#
#
#
#
#
#
#
# libcxx-21.1.0        | 555 KB    | ##################################### | 100%
#
# icu-75.1             | 11.3 MB   | ###############################3      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 541 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ######3                               |  17%
# python-3.13.1        | 12.2 MB   | ##################                    |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 541 KB    | #############1                        |  36%
#
# icu-75.1             | 11.3 MB   | ################################      |  87%
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ######5                               |  18%
# python-3.13.1        | 12.2 MB   | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
# libnghttp2-1.52.0    | 551 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 541 KB    | #############################5        |  80%
#
# icu-75.1             | 11.3 MB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ######7                               |  18%
# python-3.13.1        | 12.2 MB   | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 541 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 541 KB    | ##################################### | 100%
#
# pillow-11.3.0        | 41.0 MB   | ######8                               |  19%
# python-3.13.1        | 12.2 MB   | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsolv-0.7.35       | 418 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsolv-0.7.35       | 418 KB    | ##################3                   |  50%
#
# pillow-11.3.0        | 41.0 MB   | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ##################################### | 100%
# python-3.13.1        | 12.2 MB   | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# qhull-2020.2         | 504 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsolv-0.7.35       | 418 KB    | ################################5     |  88%
#
# pillow-11.3.0        | 41.0 MB   | #######1                              |  19%
# python-3.13.1        | 12.2 MB   | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libsolv-0.7.35       | 418 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | #######4                              |  20%
#
# icu-75.1             | 11.3 MB   | ###################################8  |  97%
# python-3.13.1        | 12.2 MB   | ####################5                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.6           | 396 KB    | ##################################### | 100%
#
# pillow-11.3.0        | 41.0 MB   | #######5                              |  20%
# python-3.13.1        | 12.2 MB   | #####################                 |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.4.0        | 341 KB    | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    | ####################################4 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    | ##################################### | 100%
#
# pillow-11.3.0        | 41.0 MB   | #######7                              |  21%
# python-3.13.1        | 12.2 MB   | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 358 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.4.0        | 341 KB    | ####################################4 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.4.0        | 341 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 316 KB    | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurl-8.4.0        | 341 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 326 KB    | #8                                    |   5%
# pillow-11.3.0        | 41.0 MB   | ########                              |  22%
#
# icu-75.1             | 11.3 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.3       | 313 KB    | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 316 KB    | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 326 KB    | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.3       | 313 KB    | #############2                        |  36%
# pillow-11.3.0        | 41.0 MB   | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 316 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 326 KB    | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 326 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 326 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 316 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 316 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.3       | 313 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.3       | 313 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# python-3.13.1        | 12.2 MB   | ######################9               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-11.3.0        | 41.0 MB   | ########7                             |  24% [A
# python-3.13.1        | 12.2 MB   | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# pillow-11.3.0        | 41.0 MB   | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# pillow-11.3.0        | 41.0 MB   | #########1                            |  25%
# pillow-11.3.0        | 41.0 MB   | #########7                            |  26%
# pillow-11.3.0        | 41.0 MB   | ##########                            |  27%
# pillow-11.3.0        | 41.0 MB   | ##########2                           |  28%
# pillow-11.3.0        | 41.0 MB   | ##########4                           |  28%
# pillow-11.3.0        | 41.0 MB   | ##########7                           |  29%
# pillow-11.3.0        | 41.0 MB   | ##########9                           |  30%
# pillow-11.3.0        | 41.0 MB   | ###########2                          |  30%
# pillow-11.3.0        | 41.0 MB   | ###########4                          |  31%
# pillow-11.3.0        | 41.0 MB   | ###########7                          |  32%
# pillow-11.3.0        | 41.0 MB   | ###########9                          |  32%
# pillow-11.3.0        | 41.0 MB   | ############2                         |  33%
# pillow-11.3.0        | 41.0 MB   | ############5                         |  34%
# pillow-11.3.0        | 41.0 MB   | ############8                         |  35%
# pillow-11.3.0        | 41.0 MB   | #############1                        |  36%
# pillow-11.3.0        | 41.0 MB   | #############5                        |  37%
# pillow-11.3.0        | 41.0 MB   | #############8                        |  37%
# pillow-11.3.0        | 41.0 MB   | ##############9                       |  40%
# pillow-11.3.0        | 41.0 MB   | ###############2                      |  41%
# pillow-11.3.0        | 41.0 MB   | ###############6                      |  42%
# pillow-11.3.0        | 41.0 MB   | ################                      |  43%
# python-3.13.1        | 12.2 MB   | ####################################3 |  98%
# pillow-11.3.0        | 41.0 MB   | ################3                     |  44%
# pillow-11.3.0        | 41.0 MB   | ##################2                   |  49%
# pillow-11.3.0        | 41.0 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ### Things to note

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

# %%
plt.plot(x, y_1, c='red', ls='dashed', lw=2)

# %%
plt.plot(x, y_1, y_2)
# Out:
# [<matplotlib.lines.Line2D at 0x12f24c410>,
#  <matplotlib.lines.Line2D at 0x12f24c550>]

# %%
plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

# %%
plt.plot(x, y_1, label='Y values',
           color='red', linestyle='dashed')

# %% [markdown]
# ## 1.2 Adding another plot

# %%
plt.plot(x, y_1, label='Y values',
           color='red', linestyle='dashed')
plt.plot(x, y_2,
         label='Y2 values', color='blue')

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')
plt.plot(x, y_2, label='Y2 values', color='blue')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

# Lets start plotting
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error,
             label='Y3 with errors', color='green')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np

# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # The math stuff
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %% [markdown]
# ### Things to note

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')                                  # For y-axis 1

plt.twinx()                                                   # This creates a new y-axis 
                                                              # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')                                 # For y-axis 2

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
#oops forgot to download the file
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 #oops forgot to download the file
# ----> 2 data = np.loadtxt('Complete_TAVG_daily.txt',
#       3                    skiprows=24)
#       4 date = data[:, 0]
#       5 anomaly = data[:, -1]
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1398             converters=converters, skiplines=skiprows, usecols=usecols,
#    1399             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1400             max_rows=max_rows, quote=quotechar)
#    1402 return arr
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_npyio_impl.py:1012, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#    1010     fname = os.fspath(fname)
#    1011 if isinstance(fname, str):
# -> 1012     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1013     if encoding is None:
#    1014         encoding = getattr(fh, 'encoding', 'latin1')
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     155 """
#     156 Open `path` with `mode` and return the file object.
#     157
#    (...)    188
#     189 """
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniconda3/lib/python3.13/site-packages/numpy/lib/_datasource.py:529, in DataSource.open(self, path, mode, encoding, newline)
#     526     return _file_openers[ext](found, mode=mode,
#     527                               encoding=encoding, newline=newline)
#     528 else:
# --> 529     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: Complete_TAVG_daily.txt not found.

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
# Your code here

# %% [markdown]
# ### Resetting styles

# %%
# Your code here
